# %% [markdown]
# # Get the XML Docs

# %%
import xml.dom.minidom as minidom
request_xml = minidom.parse('xml/ImageRequest.xml')
info_xml = minidom.parse('xml/ImageInfo.xml')

# %% [markdown]
# # Function to upload image to BetaFaceAPI

# %%
def upload_image(image_filename, request_xml):
    import base64
    import requests
    import xml.dom.minidom as minidom
    
    # encode the image as base64
    image_file = open(image_filename, 'rb')
    encoded_string = base64.b64encode(image_file.read())
    
    #insert the encoded string into the xml
    request_xml.getElementsByTagName('imagefile_data')[0].firstChild.nodeValue = encoded_string
    
    #headers for the request
    headers = {
        'Content-Type': 'application/xml'
    }
    
    #send the request
    r = requests.post('http://www.betafaceapi.com/service.svc/UploadNewImage_File', data=request_xml.toxml(), headers=headers)
    
    #get the response xml as DOM
    response_xml = minidom.parseString(r.text)
    uid = response_xml.getElementsByTagName('img_uid')[0].firstChild.nodeValue
    print "Image Filename: "+image_filename+"\t UID: "+str(uid)
    
    return uid

# %% [markdown]
# # Function to get the image info

# %%
def get_image_info(image_uid, info_xml):
    import xml.dom.minidom as minidom
    import requests
    
    # insert the UID into the xml
    info_xml.getElementsByTagName('img_uid')[0].firstChild.nodeValue = image_uid
    
    #prepare headers
    headers = {
        'Content-Type': 'application/xml'
    }
    
    #send request
    r = requests.post('http://www.betafaceapi.com/service.svc/GetImageInfo', data=info_xml.toxml(), headers=headers)
    
    return minidom.parseString(r.text)

# %% [markdown]
# # Function to get dictionary of features from xml

# %%
def get_feature_points(xml):
    import numpy as np
    
    pointInfos = xml.getElementsByTagName('PointInfo')
    
    feature_points = {}
    
    for info in pointInfos:
        name = info.getElementsByTagName('name')[0].firstChild.nodeValue
        name = name.replace(' ', '_')
        x = info.getElementsByTagName('x')[0].firstChild.nodeValue;
        y = info.getElementsByTagName('y')[0].firstChild.nodeValue;
        
        feature_points[str(name)] = {
            'x': float(x),
            'y': float(y)
        }
    return feature_points

# %% [markdown]
# # Function to calculate euclidean distance from feature name

# %%
def calculate_distance(feature_1, feature_2, feature_points):
    import numpy as np
    x = np.array([feature_points[feature_1]['x'],feature_points[feature_1]['y']])
    y = np.array([feature_points[feature_2]['x'],feature_points[feature_2]['y']])
    return np.linalg.norm(x-y)

# %% [markdown]
# # North East Indian Dataset

# %% [markdown]
# ## Form the dictionary of Image UIDs

# %%
import glob
import json

image_filenames = glob.glob('data/normalized/asian/*.jpg')

image_uids = {}
i = 0
for image_filename in image_filenames:
    i += 1
    print "Image "+str(i)+" of "+str(len(image_filenames))
    image_uids[image_filename] = upload_image(image_filename, request_xml)

# dump uid info to file
with open('data/normalized/asian_uids.json', 'w') as fp:
    json.dump(image_uids, fp)
# Out:
# Image 1 of 188
# Image Filename: data/normalized/asian\0001.jpg	 UID: 989519de-0394-40f5-97c3-25869a625c7b
# Image 2 of 188
# Image Filename: data/normalized/asian\0002.jpg	 UID: 9351f36c-36b0-4978-941e-cbbbc51d48b8
# Image 3 of 188
# Image Filename: data/normalized/asian\0003.jpg	 UID: 5c05e1af-4dd1-47ab-b37d-88365eea3613
# Image 4 of 188
# Image 171 of 188
# Image Filename: data/normalized/asian\0171.jpg	 UID: 071a07cb-3d99-416d-ab2f-0c5915a9ac13
# Image 172 of 188
# Image Filename: data/normalized/asian\0172.jpg	 UID: 0307895e-1bcf-411e-8963-6d5e131d00b4
# Image 173 of 188
# Image Filename: data/normalized/asian\0173.jpg	 UID: cb961c20-c242-4217-b1e5-cec9faffe7e9
# Image 174 of 188
# Image Filename: data/normalized/asian\0174.jpg	 UID: 7c7355ca-9666-4f03-b46c-c6cfc556b2e2
# Image 175 of 188
# Image Filename: data/normalized/asian\0175.jpg	 UID: 1b9b87da-48d4-4d69-8e9e-0bae0a753f1a
# Image 176 of 188
# Image Filename: data/normalized/asian\0176.jpg	 UID: e898b6cd-f6dc-4237-a676-88038e9ac634
# Image 177 of 188
# Image Filename: data/normalized/asian\0177.jpg	 UID: a2dc11aa-a88b-4f1e-ae21-d5c514d64d99
# Image 178 of 188
# Image Filename: data/normalized/asian\0178.jpg	 UID: cb28a975-d28a-44b4-a81d-8c065cc5133d
# Image 179 of 188
# Image Filename: data/normalized/asian\0179.jpg	 UID: d4c96f36-7b2b-4ea2-b996-dbe98c54851c
# Image 180 of 188
# Image Filename: data/normalized/asian\0180.jpg	 UID: 7bbc0837-76b4-45a1-aa9c-31a71ee55a3e
# Image 181 of 188
# Image Filename: data/normalized/asian\0181.jpg	 UID: 0ac143e4-a51d-46cb-9acc-63918ba46801
# Image 182 of 188
# Image Filename: data/normalized/asian\0182.jpg	 UID: dc0d95d2-74e4-4e7c-8877-49677e7e8128
# Image 183 of 188
# Image Filename: data/normalized/asian\0183.jpg	 UID: 4534e43a-a08f-49c9-8c4e-9b52180d1746
# Image 184 of 188
# Image Filename: data/normalized/asian\0184.jpg	 UID: cddfe868-370b-4d0c-b6c2-eb7d3f065782
# Image 185 of 188
# Image Filename: data/normalized/asian\0185.jpg	 UID: b01dfaea-4be2-4a78-9184-8699a7a68400
# Image 186 of 188
# Image Filename: data/normalized/asian\0186.jpg	 UID: 94f170be-c7a8-4a11-8000-63cc3b29ee6c
# Image 187 of 188
# Image Filename: data/normalized/asian\0187.jpg	 UID: 37317461-c411-48b4-b8f8-40a77e854506
# Image 188 of 188
# Image Filename: data/normalized/asian\0188.jpg	 UID: a3fc31b4-5266-414d-8e9c-274ed9da9414

# %% [markdown]
# ## Get features points of the images

# %%
image_infos = {}
i = 0
length = len(image_uids.keys())
for key in image_uids.keys():
    i += 1
    print "Getting feature points for image "+str(i)+" of "+str(length)
    feature_points = get_feature_points(get_image_info(image_uids[key], info_xml))
    image_infos[key] = {
        'image_uid': image_uids[key],
        'feature_points': feature_points
    }

with open('data/normalized/asian_feature_points.json', 'w') as fp:
    json.dump(image_infos, fp)
# Out:
# Getting feature points for image 1 of 188
# Getting feature points for image 2 of 188
# Getting feature points for image 3 of 188
# Getting feature points for image 4 of 188
# Getting feature points for image 5 of 188
# Getting feature points for image 6 of 188
# Getting feature points for image 7 of 188
# Getting feature points for image 8 of 188
# Getting feature points for image 9 of 188
# Getting feature points for image 10 of 188
# Getting feature points for image 11 of 188
# Getting feature points for image 12 of 188
# Getting feature points for image 13 of 188
# Getting feature points for image 14 of 188
# Getting feature points for image 15 of 188
# Getting feature points for image 16 of 188
# Getting feature points for image 17 of 188
# Getting feature points for image 18 of 188
# Getting feature points for image 19 of 188
# Getting feature points for image 20 of 188
# Getting feature points for image 21 of 188
# Getting feature points for image 22 of 188
# Getting feature points for image 23 of 188
# Getting feature points for image 24 of 188
# Getting feature points for image 25 of 188
# Getting feature points for image 26 of 188
# Getting feature points for image 27 of 188
# Getting feature points for image 28 of 188
# Getting feature points for image 29 of 188
# Getting feature points for image 30 of 188
# Getting feature points for image 31 of 188
# Getting feature points for image 32 of 188
# Getting feature points for image 33 of 188
# Getting feature points for image 34 of 188
# Getting feature points for image 35 of 188
# Getting feature points for image 36 of 188
# Getting feature points for image 37 of 188
# Getting feature points for image 38 of 188
# Getting feature points for image 39 of 188
# Getting feature points for image 40 of 188
# Getting feature points for image 41 of 188
# Getting feature points for image 42 of 188
# Getting feature points for image 43 of 188
# Getting feature points for image 44 of 188
# Getting feature points for image 45 of 188
# Getting feature points for image 46 of 188
# Getting feature points for image 47 of 188
# Getting feature points for image 48 of 188
# Getting feature points for image 49 of 188
# Getting feature points for image 50 of 188
# Getting feature points for image 51 of 188
# Getting feature points for image 52 of 188
# Getting feature points for image 53 of 188
# Getting feature points for image 54 of 188
# Getting feature points for image 55 of 188
# Getting feature points for image 56 of 188
# Getting feature points for image 57 of 188
# Getting feature points for image 58 of 188
# Getting feature points for image 59 of 188
# Getting feature points for image 60 of 188
# Getting feature points for image 61 of 188
# Getting feature points for image 62 of 188
# Getting feature points for image 63 of 188
# Getting feature points for image 64 of 188
# Getting feature points for image 65 of 188
# Getting feature points for image 66 of 188
# Getting feature points for image 67 of 188
# Getting feature points for image 68 of 188
# Getting feature points for image 69 of 188
# Getting feature points for image 70 of 188
# Getting feature points for image 71 of 188
# Getting feature points for image 72 of 188
# Getting feature points for image 73 of 188
# Getting feature points for image 74 of 188
# Getting feature points for image 75 of 188
# Getting feature points for image 76 of 188
# Getting feature points for image 77 of 188
# Getting feature points for image 78 of 188
# Getting feature points for image 79 of 188
# Getting feature points for image 80 of 188
# Getting feature points for image 81 of 188
# Getting feature points for image 82 of 188
# Getting feature points for image 83 of 188
# Getting feature points for image 84 of 188
# Getting feature points for image 85 of 188
# Getting feature points for image 86 of 188
# Getting feature points for image 87 of 188
# Getting feature points for image 88 of 188
# Getting feature points for image 89 of 188
# Getting feature points for image 90 of 188
# Getting feature points for image 91 of 188
# Getting feature points for image 92 of 188
# Getting feature points for image 93 of 188
# Getting feature points for image 94 of 188
# Getting feature points for image 95 of 188
# Getting feature points for image 96 of 188
# Getting feature points for image 97 of 188
# Getting feature points for image 98 of 188
# Getting feature points for image 99 of 188
# Getting feature points for image 100 of 188
# Getting feature points for image 101 of 188
# Getting feature points for image 102 of 188
# Getting feature points for image 103 of 188
# Getting feature points for image 104 of 188
# Getting feature points for image 105 of 188
# Getting feature points for image 106 of 188
# Getting feature points for image 107 of 188
# Getting feature points for image 108 of 188
# Getting feature points for image 109 of 188
# Getting feature points for image 110 of 188
# Getting feature points for image 111 of 188
# Getting feature points for image 112 of 188
# Getting feature points for image 113 of 188
# Getting feature points for image 114 of 188
# Getting feature points for image 115 of 188
# Getting feature points for image 116 of 188
# Getting feature points for image 117 of 188
# Getting feature points for image 118 of 188
# Getting feature points for image 119 of 188
# Getting feature points for image 120 of 188
# Getting feature points for image 121 of 188
# Getting feature points for image 122 of 188
# Getting feature points for image 123 of 188
# Getting feature points for image 124 of 188
# Getting feature points for image 125 of 188
# Getting feature points for image 126 of 188
# Getting feature points for image 127 of 188
# Getting feature points for image 128 of 188
# Getting feature points for image 129 of 188
# Getting feature points for image 130 of 188
# Getting feature points for image 131 of 188
# Getting feature points for image 132 of 188
# Getting feature points for image 133 of 188
# Getting feature points for image 134 of 188
# Getting feature points for image 135 of 188
# Getting feature points for image 136 of 188
# Getting feature points for image 137 of 188
# Getting feature points for image 138 of 188
# Getting feature points for image 139 of 188
# Getting feature points for image 140 of 188
# Getting feature points for image 141 of 188
# Getting feature points for image 142 of 188
# Getting feature points for image 143 of 188
# Getting feature points for image 144 of 188
# Getting feature points for image 145 of 188
# Getting feature points for image 146 of 188
# Getting feature points for image 147 of 188
# Getting feature points for image 148 of 188
# Getting feature points for image 149 of 188
# Getting feature points for image 150 of 188
# Getting feature points for image 151 of 188
# Getting feature points for image 152 of 188
# Getting feature points for image 153 of 188
# Getting feature points for image 154 of 188
# Getting feature points for image 155 of 188
# Getting feature points for image 156 of 188
# Getting feature points for image 157 of 188
# Getting feature points for image 158 of 188
# Getting feature points for image 159 of 188
# Getting feature points for image 160 of 188
# Getting feature points for image 161 of 188
# Getting feature points for image 162 of 188
# Getting feature points for image 163 of 188
# Getting feature points for image 164 of 188
# Getting feature points for image 165 of 188
# Getting feature points for image 166 of 188
# Getting feature points for image 167 of 188
# Getting feature points for image 168 of 188
# Getting feature points for image 169 of 188
# Getting feature points for image 170 of 188
# Getting feature points for image 171 of 188
# Getting feature points for image 172 of 188
# Getting feature points for image 173 of 188
# Getting feature points for image 174 of 188
# Getting feature points for image 175 of 188
# Getting feature points for image 176 of 188
# Getting feature points for image 177 of 188
# Getting feature points for image 178 of 188
# Getting feature points for image 179 of 188
# Getting feature points for image 180 of 188
# Getting feature points for image 181 of 188
# Getting feature points for image 182 of 188
# Getting feature points for image 183 of 188
# Getting feature points for image 184 of 188
# Getting feature points for image 185 of 188
# Getting feature points for image 186 of 188
# Getting feature points for image 187 of 188
# Getting feature points for image 188 of 188

# %%
image_infos[image_infos.keys()[0]]['feature_points']
# Out:
# {'basic_chin_bottom': {'x': 98.46, 'y': 192.79},
#  'basic_chin_left': {'x': 40.29, 'y': 131.24},
#  'basic_chin_right': {'x': 155.6, 'y': 128.83},
#  'basic_eye_left': {'x': 68.26, 'y': 98.97},
#  'basic_eye_left_inner': {'x': 79.55, 'y': 100.61},
#  'basic_eye_left_outer': {'x': 57.19, 'y': 99.63},
#  'basic_eye_right': {'x': 124.76, 'y': 99.68},
#  'basic_eye_right_inner': {'x': 113.96, 'y': 100.83},
#  'basic_eye_right_outer': {'x': 135.76, 'y': 99.92},
#  'basic_eyebrow_left': {'x': 64.25, 'y': 81.87},
#  'basic_eyebrow_left_inner_corner': {'x': 79.46, 'y': 84.93},
#  'basic_eyebrow_left_outer_corner': {'x': 49.73, 'y': 84.91},
#  'basic_eyebrow_right': {'x': 126.61, 'y': 82.87},
#  'basic_eyebrow_right_inner_corner': {'x': 111.25, 'y': 86.56},
#  'basic_eyebrow_right_outer_corner': {'x': 141.89, 'y': 84.8},
#  'basic_mouth_center': {'x': 98.65, 'y': 158.92},
#  'basic_mouth_left': {'x': 78.04, 'y': 159.71},
#  'basic_mouth_right': {'x': 118.67, 'y': 157.96},
#  'basic_nose_left': {'x': 83.24, 'y': 136.16},
#  'basic_nose_right': {'x': 110.69, 'y': 136.19},
#  'basic_nose_tip': {'x': 97.37, 'y': 130.8},
#  'cheekbone_left': {'x': 66.12, 'y': 149.68},
#  'cheekbone_right': {'x': 130.06, 'y': 150.2},
#  'chin_bottom': {'x': 98.2, 'y': 196.33},
#  'chin_ear_left': {'x': 37.93, 'y': 138.41},
#  'chin_ear_right': {'x': 156.74, 'y': 136.14},
#  'chin_left_1': {'x': 41.63, 'y': 153.14},
#  'chin_left_2': {'x': 47.88, 'y': 166.56},
#  'chin_left_3': {'x': 57.49, 'y': 177.99},
#  'chin_left_4': {'x': 69.42, 'y': 187.15},
#  'chin_left_5': {'x': 82.89, 'y': 194.23},
#  'chin_right_1': {'x': 153.71, 'y': 151.0},
#  'chin_right_2': {'x': 148.0, 'y': 164.74},
#  'chin_right_3': {'x': 138.83, 'y': 176.61},
#  'chin_right_4': {'x': 127.05, 'y': 186.26},
#  'chin_right_5': {'x': 113.57, 'y': 193.81},
#  'eye_left_bottom': {'x': 69.37, 'y': 102.19},
#  'eye_left_bottom_inner': {'x': 74.97, 'y': 102.32},
#  'eye_left_bottom_outer': {'x': 64.7, 'y': 101.94},
#  'eye_left_inner': {'x': 81.11, 'y': 100.85},
#  'eye_left_iris': {'x': 70.87, 'y': 98.27},
#  'eye_left_outer': {'x': 58.77, 'y': 99.17},
#  'eye_left_top': {'x': 70.03, 'y': 94.68},
#  'eye_left_top_inner': {'x': 75.62, 'y': 96.43},
#  'eye_left_top_outer': {'x': 64.93, 'y': 96.1},
#  'eye_right_bottom': {'x': 126.98, 'y': 102.33},
#  'eye_right_bottom_inner': {'x': 122.03, 'y': 102.2},
#  'eye_right_bottom_outer': {'x': 130.9, 'y': 101.69},
#  'eye_right_inner': {'x': 115.54, 'y': 101.01},
#  'eye_right_iris': {'x': 125.9, 'y': 98.4},
#  'eye_right_outer': {'x': 136.89, 'y': 98.93},
#  'eye_right_top': {'x': 126.23, 'y': 94.77},
#  'eye_right_top_inner': {'x': 121.34, 'y': 96.25},
#  'eye_right_top_outer': {'x': 130.48, 'y': 95.74},
#  'eyebrow_left_bottom': {'x': 67.69, 'y': 84.15},
#  'eyebrow_left_bottom_inner': {'x': 76.28, 'y': 86.93},
#  'eyebrow_left_bottom_outer': {'x': 59.39, 'y': 84.36},
#  'eyebrow_left_inner': {'x': 84.73, 'y': 87.85},
#  'eyebrow_left_outer': {'x': 51.13, 'y': 85.8},
#  'eyebrow_left_top': {'x': 68.33, 'y': 77.05},
#  'eyebrow_left_top_inner': {'x': 79.8, 'y': 80.77},
#  'eyebrow_left_top_outer': {'x': 57.77, 'y': 78.32},
#  'eyebrow_right_botom': {'x': 129.69, 'y': 85.16},
#  'eyebrow_right_bottom_outer': {'x': 137.77, 'y': 85.36},
#  'eyebrow_right_inner': {'x': 112.84, 'y': 88.49},
#  'eyebrow_right_outer': {'x': 145.57, 'y': 86.28},
#  'eyebrow_right_top': {'x': 129.07, 'y': 78.29},
#  'eyebrow_right_top_inner': {'x': 117.99, 'y': 81.71},
#  'eyebrow_right_top_outer': {'x': 139.21, 'y': 79.42},
#  'eyebrow_rigth_bottom_inner': {'x': 121.26, 'y': 87.69},
#  'forehead_1': {'x': 64.97, 'y': 65.27},
#  'forehead_2': {'x': 81.58, 'y': 64.61},
#  'forehead_3': {'x': 116.25, 'y': 64.92},
#  'forehead_4': {'x': 132.8, 'y': 65.88},
#  'forehead_left': {'x': 48.97, 'y': 66.84},
#  'forehead_middle': {'x': 98.94, 'y': 64.39},
#  'forehead_right': {'x': 148.74, 'y': 67.72},
#  'mouth_bottom': {'x': 100.99, 'y': 169.27},
#  'mouth_inner_bottom': {'x': 100.94, 'y': 159.51},
#  'mouth_inner_left': {'x': 82.41, 'y': 160.2},
#  'mouth_inner_left_bottom': {'x': 95.33, 'y': 159.26},
#  'mouth_inner_left_top': {'x': 95.42, 'y': 158.49},
#  'mouth_inner_right': {'x': 117.26, 'y': 159.03},
#  'mouth_inner_right_bottom': {'x': 106.36, 'y': 158.77},
#  'mouth_inner_right_top': {'x': 106.41, 'y': 158.09},
#  'mouth_inner_top': {'x': 101.02, 'y': 158.79},
#  'mouth_left': {'x': 78.79, 'y': 160.12},
#  'mouth_left_bottom': {'x': 92.93, 'y': 168.6},
#  'mouth_left_bottom_point_1': {'x': 85.84, 'y': 165.28},
#  'mouth_left_top': {'x': 93.97, 'y': 151.16},
#  'mouth_left_top_point_1': {'x': 86.22, 'y': 154.71},
#  'mouth_right': {'x': 121.32, 'y': 158.47},
#  'mouth_right_bottom': {'x': 108.93, 'y': 167.89},
#  'mouth_right_bottom_point_1': {'x': 115.6, 'y': 163.95},
#  'mouth_right_top': {'x': 106.4, 'y': 150.61},
#  'mouth_right_top_point_1': {'x': 114.31, 'y': 153.46},
#  'mouth_top': {'x': 100.25, 'y': 152.35},
#  'nose_bottom': {'x': 97.8, 'y': 140.99},
#  'nose_bridge_bottom': {'x': 98.23, 'y': 118.13},
#  'nose_bridge_middle': {'x': 98.58, 'y': 108.24},
#  'nose_bridge_top': {'x': 98.98, 'y': 98.21},
#  'nose_left_bottom_inner': {'x': 90.19, 'y': 137.23},
#  'nose_left_bottom_outer': {'x': 84.03, 'y': 138.82},
#  'nose_left_top': {'x': 90.61, 'y': 101.92},
#  'nose_left_top_inner': {'x': 87.3, 'y': 120.85},
#  'nose_left_top_outer': {'x': 80.85, 'y': 130.55},
#  'nose_right_bottom_inner': {'x': 105.58, 'y': 137.23},
#  'nose_right_bottom_outer': {'x': 111.99, 'y': 138.92},
#  'nose_right_top': {'x': 106.57, 'y': 102.04},
#  'nose_right_top_inner': {'x': 109.75, 'y': 121.03},
#  'nose_right_top_outer': {'x': 116.01, 'y': 130.84},
#  'nose_tip': {'x': 97.27, 'y': 128.94},
#  'temple_left': {'x': 42.88, 'y': 75.04},
#  'temple_left_1': {'x': 36.8, 'y': 83.25},
#  'temple_left_2': {'x': 35.51, 'y': 95.38},
#  'temple_left_3': {'x': 34.23, 'y': 107.5},
#  'temple_left_4': {'x': 35.61, 'y': 123.32},
#  'temple_right': {'x': 154.04, 'y': 75.47},
#  'temple_right_1': {'x': 159.35, 'y': 83.22},
#  'temple_right_2': {'x': 159.22, 'y': 94.26},
#  'temple_right_3': {'x': 159.08, 'y': 105.3},
#  'temple_right_4': {'x': 158.33, 'y': 121.06}}

# %% [markdown]
# # Calculate the necessary features and build SFrame

# %%
import graphlab as gl
from graphlab import SFrame

image_features = {}
length = len(image_infos.keys())
i = 0
data = None
for key in image_infos.keys():
    i += 1
    feature_points = image_infos[key]['feature_points']
    features = {
        'filename': [key[22:]],
        'eye_outer': [calculate_distance('basic_eye_left_outer', 'basic_eye_right_outer', feature_points)],
        'eye_inner': [calculate_distance('basic_eye_left_inner', 'basic_eye_right_inner', feature_points)],
        'eye': [calculate_distance('basic_eye_left', 'basic_eye_right', feature_points)],
        'mouth': [calculate_distance('basic_mouth_left', 'basic_mouth_right', feature_points)],
        'nose_mouth': [calculate_distance('basic_nose_tip', 'basic_mouth_center', feature_points)],
        'eyebrow_inner': [calculate_distance('basic_eyebrow_left_inner_corner', 'basic_eyebrow_right_inner_corner', feature_points)],
        'eyebrow_outer': [calculate_distance('basic_eyebrow_left_outer_corner', 'basic_eyebrow_right_outer_corner', feature_points)],
        'chin': [calculate_distance('basic_chin_left', 'basic_chin_right', feature_points)],
        'nose': [calculate_distance('basic_nose_left', 'basic_nose_right', feature_points)],
        'chin_mouth': [calculate_distance('basic_chin_bottom', 'basic_mouth_center', feature_points)],
        'ethnicity': [1]
    }
    image_features[key] = {
        'image_uid': image_infos[key]['image_uid'],
        'features': features
    }
    
    #create the SFrame
    if data is None:
        data = SFrame(features)
    else:
        data = data.append(SFrame(features))

# %% [markdown]
# # Save the SFrame for later use

# %%
data.save('data/normalized/asian_sframe')

# %% [markdown]
# # Rest of India Dataset

# %% [markdown]
# ## Form dictionary of image UIDs

# %%
import glob
import json

image_filenames = glob.glob('data/normalized/non-asian/*.jpg')

image_uids = {}
i = 0
for image_filename in image_filenames:
    i += 1
    print "Image "+str(i)+" of "+str(len(image_filenames))
    image_uids[image_filename] = upload_image(image_filename, request_xml)

# dump uid info to file
with open('data/normalized/non_asian_uids.json', 'w') as fp:
    json.dump(image_uids, fp)
# Out:
# Image 1 of 110
# Image Filename: data/normalized/non-asian\0093.jpg	 UID: 35424e21-be7e-41f6-a326-86d9f094857e
# Image 94 of 110
# Image Filename: data/normalized/non-asian\0094.jpg	 UID: 7cedef85-7b26-4644-b44b-5641363ded1a
# Image 95 of 110
# Image Filename: data/normalized/non-asian\0095.jpg	 UID: 79f94644-342d-407a-8a36-4d2ace5fdfc7
# Image 96 of 110
# Image Filename: data/normalized/non-asian\0096.jpg	 UID: 0345fbd7-716d-4a71-b84e-6b02a1608002
# Image 97 of 110
# Image Filename: data/normalized/non-asian\0097.jpg	 UID: c2b4e2b9-62c8-4b5e-bcc7-6064dc60043e
# Image 98 of 110
# Image Filename: data/normalized/non-asian\0098.jpg	 UID: 2be22782-dd01-4994-aca8-5972b4dfd9b5
# Image 99 of 110
# Image Filename: data/normalized/non-asian\0099.jpg	 UID: 80734eac-9b78-4b41-94ca-15b8c640c8e9
# Image 100 of 110
# Image Filename: data/normalized/non-asian\0100.jpg	 UID: 493c56ab-9aa9-461f-ae27-c9076adee730
# Image 101 of 110
# Image Filename: data/normalized/non-asian\0101.jpg	 UID: 7011a019-9d64-4f08-b5e5-ac6be2f69c9b
# Image 102 of 110
# Image Filename: data/normalized/non-asian\0102.jpg	 UID: d7d8174a-8dc1-42bd-ae74-56b158ad5b5f
# Image 103 of 110
# Image Filename: data/normalized/non-asian\0103.jpg	 UID: bf0d1b9a-749f-448e-a779-1158f7ba6912
# Image 104 of 110
# Image Filename: data/normalized/non-asian\0104.jpg	 UID: 2d997e5f-59f0-4320-b07c-e15ae0032c49
# Image 105 of 110
# Image Filename: data/normalized/non-asian\0105.jpg	 UID: 0a7ac5c4-42ca-4b7a-8a45-85c86446ec6d
# Image 106 of 110
# Image Filename: data/normalized/non-asian\0106.jpg	 UID: 1b19023d-1319-4ad0-9f86-82d260bf20ce
# Image 107 of 110
# Image Filename: data/normalized/non-asian\0107.jpg	 UID: 9831e2d4-dc21-475d-8a31-ef0302b2e1df
# Image 108 of 110
# Image Filename: data/normalized/non-asian\0108.jpg	 UID: 075c185e-2e2e-4c72-8958-ea62d8b2559d
# Image 109 of 110
# Image Filename: data/normalized/non-asian\0109.jpg	 UID: 9c9e20bb-852e-4394-89a6-e32832c70298
# Image 110 of 110
# Image Filename: data/normalized/non-asian\0110.jpg	 UID: 9470bb06-78c9-4f99-ba54-643f7a6f4a31

# %% [markdown]
# ## Get feature points of the images

# %%
image_infos = {}
i = 0
length = len(image_uids.keys())
for key in image_uids.keys():
    i += 1
    print "Getting feature points for image "+str(i)+" of "+str(length)
    feature_points = get_feature_points(get_image_info(image_uids[key], info_xml))
    image_infos[key] = {
        'image_uid': image_uids[key],
        'feature_points': feature_points
    }

with open('data/normalized/non_asian_feature_points.json', 'w') as fp:
    json.dump(image_infos, fp)
# Out:
# Getting feature points for image 1 of 110
# Getting feature points for image 2 of 110
# Getting feature points for image 3 of 110
# Getting feature points for image 4 of 110
# Getting feature points for image 5 of 110
# Getting feature points for image 6 of 110
# Getting feature points for image 7 of 110
# Getting feature points for image 8 of 110
# Getting feature points for image 9 of 110
# Getting feature points for image 10 of 110
# Getting feature points for image 11 of 110
# Getting feature points for image 12 of 110
# Getting feature points for image 13 of 110
# Getting feature points for image 14 of 110
# Getting feature points for image 15 of 110
# Getting feature points for image 16 of 110
# Getting feature points for image 17 of 110
# Getting feature points for image 18 of 110
# Getting feature points for image 19 of 110
# Getting feature points for image 20 of 110
# Getting feature points for image 21 of 110
# Getting feature points for image 22 of 110
# Getting feature points for image 23 of 110
# Getting feature points for image 24 of 110
# Getting feature points for image 25 of 110
# Getting feature points for image 26 of 110
# Getting feature points for image 27 of 110
# Getting feature points for image 28 of 110
# Getting feature points for image 29 of 110
# Getting feature points for image 30 of 110
# Getting feature points for image 31 of 110
# Getting feature points for image 32 of 110
# Getting feature points for image 33 of 110
# Getting feature points for image 34 of 110
# Getting feature points for image 35 of 110
# Getting feature points for image 36 of 110
# Getting feature points for image 37 of 110
# Getting feature points for image 38 of 110
# Getting feature points for image 39 of 110
# Getting feature points for image 40 of 110
# Getting feature points for image 41 of 110
# Getting feature points for image 42 of 110
# Getting feature points for image 43 of 110
# Getting feature points for image 44 of 110
# Getting feature points for image 45 of 110
# Getting feature points for image 46 of 110
# Getting feature points for image 47 of 110
# Getting feature points for image 48 of 110
# Getting feature points for image 49 of 110
# Getting feature points for image 50 of 110
# Getting feature points for image 51 of 110
# Getting feature points for image 52 of 110
# Getting feature points for image 53 of 110
# Getting feature points for image 54 of 110
# Getting feature points for image 55 of 110
# Getting feature points for image 56 of 110
# Getting feature points for image 57 of 110
# Getting feature points for image 58 of 110
# Getting feature points for image 59 of 110
# Getting feature points for image 60 of 110
# Getting feature points for image 61 of 110
# Getting feature points for image 62 of 110
# Getting feature points for image 63 of 110
# Getting feature points for image 64 of 110
# Getting feature points for image 65 of 110
# Getting feature points for image 66 of 110
# Getting feature points for image 67 of 110
# Getting feature points for image 68 of 110
# Getting feature points for image 69 of 110
# Getting feature points for image 70 of 110
# Getting feature points for image 71 of 110
# Getting feature points for image 72 of 110
# Getting feature points for image 73 of 110
# Getting feature points for image 74 of 110
# Getting feature points for image 75 of 110
# Getting feature points for image 76 of 110
# Getting feature points for image 77 of 110
# Getting feature points for image 78 of 110
# Getting feature points for image 79 of 110
# Getting feature points for image 80 of 110
# Getting feature points for image 81 of 110
# Getting feature points for image 82 of 110
# Getting feature points for image 83 of 110
# Getting feature points for image 84 of 110
# Getting feature points for image 85 of 110
# Getting feature points for image 86 of 110
# Getting feature points for image 87 of 110
# Getting feature points for image 88 of 110
# Getting feature points for image 89 of 110
# Getting feature points for image 90 of 110
# Getting feature points for image 91 of 110
# Getting feature points for image 92 of 110
# Getting feature points for image 93 of 110
# Getting feature points for image 94 of 110
# Getting feature points for image 95 of 110
# Getting feature points for image 96 of 110
# Getting feature points for image 97 of 110
# Getting feature points for image 98 of 110
# Getting feature points for image 99 of 110
# Getting feature points for image 100 of 110
# Getting feature points for image 101 of 110
# Getting feature points for image 102 of 110
# Getting feature points for image 103 of 110
# Getting feature points for image 104 of 110
# Getting feature points for image 105 of 110
# Getting feature points for image 106 of 110
# Getting feature points for image 107 of 110
# Getting feature points for image 108 of 110
# Getting feature points for image 109 of 110
# Getting feature points for image 110 of 110

# %% [markdown]
# ## Calculate necessary features and build SFrame

# %%
import graphlab as gl
from graphlab import SFrame

image_features = {}
length = len(image_infos.keys())
i = 0
data2 = None
for key in image_infos.keys():
    print key
    i += 1
    feature_points = image_infos[key]['feature_points']
    features = {
        'filename': [key[26:]],
        'eye_outer': [calculate_distance('basic_eye_left_outer', 'basic_eye_right_outer', feature_points)],
        'eye_inner': [calculate_distance('basic_eye_left_inner', 'basic_eye_right_inner', feature_points)],
        'eye': [calculate_distance('basic_eye_left', 'basic_eye_right', feature_points)],
        'mouth': [calculate_distance('basic_mouth_left', 'basic_mouth_right', feature_points)],
        'nose_mouth': [calculate_distance('basic_nose_tip', 'basic_mouth_center', feature_points)],
        'eyebrow_inner': [calculate_distance('basic_eyebrow_left_inner_corner', 'basic_eyebrow_right_inner_corner', feature_points)],
        'eyebrow_outer': [calculate_distance('basic_eyebrow_left_outer_corner', 'basic_eyebrow_right_outer_corner', feature_points)],
        'chin': [calculate_distance('basic_chin_left', 'basic_chin_right', feature_points)],
        'nose': [calculate_distance('basic_nose_left', 'basic_nose_right', feature_points)],
        'chin_mouth': [calculate_distance('basic_chin_bottom', 'basic_mouth_center', feature_points)],
        'ethnicity': [0]
    }
    image_features[key] = {
        'image_uid': image_infos[key]['image_uid'],
        'features': features
    }
    
    #create the SFrame
    if data2 is None:
        data2 = SFrame(features)
    else:
        data2 = data2.append(SFrame(features))
# Out:
# data/normalized/non-asian\0008.jpg
# data/normalized/non-asian\0082.jpg
# data/normalized/non-asian\0024.jpg
# data/normalized/non-asian\0050.jpg
# data/normalized/non-asian\0055.jpg
# data/normalized/non-asian\0038.jpg
# data/normalized/non-asian\0015.jpg
# data/normalized/non-asian\0068.jpg
# data/normalized/non-asian\0075.jpg
# data/normalized/non-asian\0019.jpg
# data/normalized/non-asian\0092.jpg
# data/normalized/non-asian\0090.jpg
# data/normalized/non-asian\0003.jpg
# data/normalized/non-asian\0017.jpg
# data/normalized/non-asian\0084.jpg
# data/normalized/non-asian\0037.jpg
# data/normalized/non-asian\0028.jpg
# data/normalized/non-asian\0094.jpg
# data/normalized/non-asian\0044.jpg
# data/normalized/non-asian\0027.jpg
# data/normalized/non-asian\0095.jpg
# data/normalized/non-asian\0048.jpg
# data/normalized/non-asian\0063.jpg
# data/normalized/non-asian\0020.jpg
# data/normalized/non-asian\0072.jpg
# data/normalized/non-asian\0013.jpg
# data/normalized/non-asian\0014.jpg
# data/normalized/non-asian\0085.jpg
# data/normalized/non-asian\0101.jpg
# data/normalized/non-asian\0034.jpg
# data/normalized/non-asian\0069.jpg
# data/normalized/non-asian\0093.jpg
# data/normalized/non-asian\0070.jpg
# data/normalized/non-asian\0007.jpg
# data/normalized/non-asian\0026.jpg
# data/normalized/non-asian\0045.jpg
# data/normalized/non-asian\0098.jpg
# data/normalized/non-asian\0073.jpg
# data/normalized/non-asian\0021.jpg
# data/normalized/non-asian\0065.jpg
# data/normalized/non-asian\0011.jpg
# data/normalized/non-asian\0047.jpg
# data/normalized/non-asian\0002.jpg
# data/normalized/non-asian\0023.jpg
# data/normalized/non-asian\0042.jpg
# data/normalized/non-asian\0036.jpg
# data/normalized/non-asian\0079.jpg
# data/normalized/non-asian\0109.jpg
# data/normalized/non-asian\0006.jpg
# data/normalized/non-asian\0049.jpg
# data/normalized/non-asian\0081.jpg
# data/normalized/non-asian\0097.jpg
# data/normalized/non-asian\0076.jpg
# data/normalized/non-asian\0107.jpg
# data/normalized/non-asian\0071.jpg
# data/normalized/non-asian\0030.jpg
# data/normalized/non-asian\0099.jpg
# data/normalized/non-asian\0012.jpg
# data/normalized/non-asian\0074.jpg
# data/normalized/non-asian\0110.jpg
# data/normalized/non-asian\0061.jpg
# data/normalized/non-asian\0086.jpg
# data/normalized/non-asian\0039.jpg
# data/normalized/non-asian\0041.jpg
# data/normalized/non-asian\0096.jpg
# data/normalized/non-asian\0067.jpg
# data/normalized/non-asian\0051.jpg
# data/normalized/non-asian\0064.jpg
# data/normalized/non-asian\0004.jpg
# data/normalized/non-asian\0058.jpg
# data/normalized/non-asian\0009.jpg
# data/normalized/non-asian\0083.jpg
# data/normalized/non-asian\0104.jpg
# data/normalized/non-asian\0059.jpg
# data/normalized/non-asian\0010.jpg
# data/normalized/non-asian\0001.jpg
# data/normalized/non-asian\0103.jpg
# data/normalized/non-asian\0056.jpg
# data/normalized/non-asian\0043.jpg
# data/normalized/non-asian\0060.jpg
# data/normalized/non-asian\0066.jpg
# data/normalized/non-asian\0040.jpg
# data/normalized/non-asian\0091.jpg
# data/normalized/non-asian\0022.jpg
# data/normalized/non-asian\0088.jpg
# data/normalized/non-asian\0077.jpg
# data/normalized/non-asian\0053.jpg
# data/normalized/non-asian\0016.jpg
# data/normalized/non-asian\0078.jpg
# data/normalized/non-asian\0025.jpg
# data/normalized/non-asian\0080.jpg
# data/normalized/non-asian\0033.jpg
# data/normalized/non-asian\0106.jpg
# data/normalized/non-asian\0105.jpg
# data/normalized/non-asian\0054.jpg
# data/normalized/non-asian\0057.jpg
# data/normalized/non-asian\0102.jpg
# data/normalized/non-asian\0087.jpg
# data/normalized/non-asian\0029.jpg
# data/normalized/non-asian\0031.jpg
# data/normalized/non-asian\0062.jpg
# data/normalized/non-asian\0100.jpg
# data/normalized/non-asian\0108.jpg
# data/normalized/non-asian\0005.jpg
# data/normalized/non-asian\0018.jpg
# data/normalized/non-asian\0035.jpg
# data/normalized/non-asian\0052.jpg
# data/normalized/non-asian\0046.jpg
# data/normalized/non-asian\0032.jpg
# data/normalized/non-asian\0089.jpg

# %% [markdown]
# ## Save the SFrame for later use

# %%
data2.save('data/normalized/non_asian_sframe')

# %% [markdown]
# # Hispanic Dataset

# %% [markdown]
# ## Form the dictionary of image UIDs

# %%
import glob
import json

image_filenames = glob.glob('data/normalized/hispanic/*.jpg')

image_uids = {}
i = 0
for image_filename in image_filenames:
    i += 1
    print "Image "+str(i)+" of "+str(len(image_filenames))
    image_uids[image_filename] = upload_image(image_filename, request_xml)

# dump uid info to file
with open('data/normalized/hispanic_uids.json', 'w') as fp:
    json.dump(image_uids, fp)
# Out:
# Image 1 of 48
# Image Filename: data/normalized/hispanic\0001.jpg	 UID: 52aa3da6-a35a-488e-b7c6-40801c3d318d
# Image 2 of 48
# Image Filename: data/normalized/hispanic\0002.jpg	 UID: afbcad01-a6c9-4a16-adad-c917da95c875
# Image 3 of 48
# Image Filename: data/normalized/hispanic\0003.jpg	 UID: 0ffd1640-21f1-49e5-8173-efaf15e64687
# Image 4 of 48
# Image Filename: data/normalized/hispanic\0004.jpg	 UID: 623f0840-e6f8-4e1c-9731-c65642c8ffa7
# Image 5 of 48
# Image Filename: data/normalized/hispanic\0005.jpg	 UID: 683b9c30-c9ad-499b-bca2-ea7a8bb70c9f
# Image 6 of 48
# Image Filename: data/normalized/hispanic\0006.jpg	 UID: 621cd6ed-4ff0-4082-93a1-36a5bc241202
# Image 7 of 48
# Image Filename: data/normalized/hispanic\0007.jpg	 UID: f50705be-169c-487a-b221-7346018376fc
# Image 8 of 48
# Image Filename: data/normalized/hispanic\0008.jpg	 UID: d19ff0d7-f012-4f0a-974f-9ed973d58425
# Image 9 of 48
# Image Filename: data/normalized/hispanic\0009.jpg	 UID: 81694156-811c-43e0-9b54-63281ad4a307
# Image 10 of 48
# Image Filename: data/normalized/hispanic\0010.jpg	 UID: f7a63c5d-ed84-4da7-96ce-772c21312d46
# Image 11 of 48
# Image Filename: data/normalized/hispanic\0011.jpg	 UID: 69e6de16-8c82-4b84-9869-f3466a7934f7
# Image 12 of 48
# Image Filename: data/normalized/hispanic\0012.jpg	 UID: 295c3b84-3d2f-496f-9da5-e320540963db
# Image 13 of 48
# Image Filename: data/normalized/hispanic\0013.jpg	 UID: 7a5be94b-dcbd-48e6-8868-6cdcf09d6704
# Image 14 of 48
# Image Filename: data/normalized/hispanic\0014.jpg	 UID: e3349500-3445-493d-b1be-6db85bd7856e
# Image 15 of 48
# Image Filename: data/normalized/hispanic\0015.jpg	 UID: a28f5f8f-ad56-4b17-a04d-83764fc8d573
# Image 16 of 48
# Image Filename: data/normalized/hispanic\0016.jpg	 UID: 6ef67476-72d1-4235-82ce-6052ee35b303
# Image 17 of 48
# Image Filename: data/normalized/hispanic\0017.jpg	 UID: 46a70587-d115-4e57-ba1c-fcac0e1e51c8
# Image 18 of 48
# Image Filename: data/normalized/hispanic\0018.jpg	 UID: 35e7b578-d631-4849-b0e0-15255330f463
# Image 19 of 48
# Image Filename: data/normalized/hispanic\0019.jpg	 UID: 23d469d9-6844-4172-89ad-96138d1e1820
# Image 20 of 48
# Image Filename: data/normalized/hispanic\0020.jpg	 UID: 2afe418f-532d-4f23-8b98-12479463ce85
# Image 21 of 48
# Image Filename: data/normalized/hispanic\0021.jpg	 UID: a1693131-1ab6-422c-bab3-0264e7747998
# Image 22 of 48
# Image Filename: data/normalized/hispanic\0022.jpg	 UID: f48bc808-6a52-4a30-919a-09f08a86a30b
# Image 23 of 48
# Image Filename: data/normalized/hispanic\0046.jpg	 UID: c0134e8a-e873-4675-8e03-e3450859fba5
# Image 47 of 48
# Image Filename: data/normalized/hispanic\0047.jpg	 UID: 92feca7b-696f-4f8d-be28-1a747184bc8a
# Image 48 of 48
# Image Filename: data/normalized/hispanic\0048.jpg	 UID: 86e421ea-69cd-40fb-9e35-59932f1dd03e

# %% [markdown]
# ## Get feature points of the images

# %%
image_infos = {}
i = 0
length = len(image_uids.keys())
for key in image_uids.keys():
    i += 1
    print "Getting feature points for image "+str(i)+" of "+str(length)
    feature_points = get_feature_points(get_image_info(image_uids[key], info_xml))
    image_infos[key] = {
        'image_uid': image_uids[key],
        'feature_points': feature_points
    }

with open('data/normalized/hispanic_feature_points.json', 'w') as fp:
    json.dump(image_infos, fp)
# Out:
# Getting feature points for image 1 of 48
# Getting feature points for image 2 of 48
# Getting feature points for image 3 of 48
# Getting feature points for image 4 of 48
# Getting feature points for image 5 of 48
# Getting feature points for image 6 of 48
# Getting feature points for image 7 of 48
# Getting feature points for image 8 of 48
# Getting feature points for image 9 of 48
# Getting feature points for image 10 of 48
# Getting feature points for image 11 of 48
# Getting feature points for image 12 of 48
# Getting feature points for image 13 of 48
# Getting feature points for image 14 of 48
# Getting feature points for image 15 of 48
# Getting feature points for image 16 of 48
# Getting feature points for image 17 of 48
# Getting feature points for image 18 of 48
# Getting feature points for image 19 of 48
# Getting feature points for image 20 of 48
# Getting feature points for image 21 of 48
# Getting feature points for image 22 of 48
# Getting feature points for image 23 of 48
# Getting feature points for image 24 of 48
# Getting feature points for image 25 of 48
# Getting feature points for image 26 of 48
# Getting feature points for image 27 of 48
# Getting feature points for image 28 of 48
# Getting feature points for image 29 of 48
# Getting feature points for image 30 of 48
# Getting feature points for image 31 of 48
# Getting feature points for image 32 of 48
# Getting feature points for image 33 of 48
# Getting feature points for image 34 of 48
# Getting feature points for image 35 of 48
# Getting feature points for image 36 of 48
# Getting feature points for image 37 of 48
# Getting feature points for image 38 of 48
# Getting feature points for image 39 of 48
# Getting feature points for image 40 of 48
# Getting feature points for image 41 of 48
# Getting feature points for image 42 of 48
# Getting feature points for image 43 of 48
# Getting feature points for image 44 of 48
# Getting feature points for image 45 of 48
# Getting feature points for image 46 of 48
# Getting feature points for image 47 of 48
# Getting feature points for image 48 of 48

# %% [markdown]
# ## Calculate necessary features and build SFrame

# %%
import graphlab as gl
from graphlab import SFrame

image_features = {}
length = len(image_infos.keys())
i = 0
data3 = None
for key in image_infos.keys():
    print key
    i += 1
    feature_points = image_infos[key]['feature_points']
    features = {
        'filename': [key[26:]],
        'eye_outer': [calculate_distance('basic_eye_left_outer', 'basic_eye_right_outer', feature_points)],
        'eye_inner': [calculate_distance('basic_eye_left_inner', 'basic_eye_right_inner', feature_points)],
        'eye': [calculate_distance('basic_eye_left', 'basic_eye_right', feature_points)],
        'mouth': [calculate_distance('basic_mouth_left', 'basic_mouth_right', feature_points)],
        'nose_mouth': [calculate_distance('basic_nose_tip', 'basic_mouth_center', feature_points)],
        'eyebrow_inner': [calculate_distance('basic_eyebrow_left_inner_corner', 'basic_eyebrow_right_inner_corner', feature_points)],
        'eyebrow_outer': [calculate_distance('basic_eyebrow_left_outer_corner', 'basic_eyebrow_right_outer_corner', feature_points)],
        'chin': [calculate_distance('basic_chin_left', 'basic_chin_right', feature_points)],
        'nose': [calculate_distance('basic_nose_left', 'basic_nose_right', feature_points)],
        'chin_mouth': [calculate_distance('basic_chin_bottom', 'basic_mouth_center', feature_points)],
        'ethnicity': [2]
    }
    image_features[key] = {
        'image_uid': image_infos[key]['image_uid'],
        'features': features
    }
    
    #create the SFrame
    if data3 is None:
        data3 = SFrame(features)
    else:
        data3 = data3.append(SFrame(features))
# Out:
# data/normalized/hispanic\0016.jpg
# data/normalized/hispanic\0019.jpg
# data/normalized/hispanic\0044.jpg
# data/normalized/hispanic\0007.jpg
# data/normalized/hispanic\0035.jpg
# data/normalized/hispanic\0047.jpg
# data/normalized/hispanic\0041.jpg
# data/normalized/hispanic\0034.jpg
# data/normalized/hispanic\0008.jpg
# data/normalized/hispanic\0021.jpg
# data/normalized/hispanic\0048.jpg
# data/normalized/hispanic\0014.jpg
# data/normalized/hispanic\0012.jpg
# data/normalized/hispanic\0040.jpg
# data/normalized/hispanic\0009.jpg
# data/normalized/hispanic\0024.jpg
# data/normalized/hispanic\0022.jpg
# data/normalized/hispanic\0045.jpg
# data/normalized/hispanic\0020.jpg
# data/normalized/hispanic\0002.jpg
# data/normalized/hispanic\0029.jpg
# data/normalized/hispanic\0013.jpg
# data/normalized/hispanic\0006.jpg
# data/normalized/hispanic\0036.jpg
# data/normalized/hispanic\0030.jpg
# data/normalized/hispanic\0001.jpg
# data/normalized/hispanic\0010.jpg
# data/normalized/hispanic\0043.jpg
# data/normalized/hispanic\0026.jpg
# data/normalized/hispanic\0023.jpg
# data/normalized/hispanic\0017.jpg
# data/normalized/hispanic\0038.jpg
# data/normalized/hispanic\0027.jpg
# data/normalized/hispanic\0032.jpg
# data/normalized/hispanic\0003.jpg
# data/normalized/hispanic\0005.jpg
# data/normalized/hispanic\0046.jpg
# data/normalized/hispanic\0039.jpg
# data/normalized/hispanic\0042.jpg
# data/normalized/hispanic\0037.jpg
# data/normalized/hispanic\0018.jpg
# data/normalized/hispanic\0031.jpg
# data/normalized/hispanic\0033.jpg
# data/normalized/hispanic\0015.jpg
# data/normalized/hispanic\0004.jpg
# data/normalized/hispanic\0011.jpg
# data/normalized/hispanic\0025.jpg
# data/normalized/hispanic\0028.jpg

# %% [markdown]
# ## Save the SFrame for later use

# %%
data3.save('data/normalized/hispanic_sframe')

# %% [markdown]
# # Combine the 2 SFrames and shuffle

# %%
asian_data, asian_temp = data.random_split(0.665, seed=5)
features_sframe = asian_data.append(data2)
print len(asian_data)
print len(data2)
print len(features_sframe)
# Out:
# 118
# 110
# 228

# %%
train_data, test_data = features_sframe.random_split(.9, seed=5)
test_data = test_data.append(asian_temp)
print len(train_data)
print len(test_data)
print len(test_data[test_data['ethnicity'] == 1])
# Out:
# 200
# 98
# 87

# %%
train_data.save('data/train_data_sframe')
test_data.save('data/test_date_sframe')
